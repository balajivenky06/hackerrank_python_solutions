# %% [markdown]
# # Anagram

# %%
from IPython.display import Image
from IPython.display import display

# %%
a = Image(r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Anagram.png')
b = Image(r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Anagram1.png')
c = Image(r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Anagram2.png')
display(a,b,c)

# %%
import math
import os
import random
import re
import sys

# Complete the anagram function below.
def anagram(s):
    if len(s)%2 != 0:
        print("-1")
    else:
        s1 = s[:len(s)//2]
        print(s1)
        s2 = s[(len(s)//2):]
        print(s2)
        cnt = 0
        for i in s1:
            print(i)
            if i not in s2:
                cnt+=1
        print(cnt)
    
    
if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    q = int(input())

    for q_itr in range(q):
        s = input()

        result = anagram(s)

        #fptr.write(str(result) + '\n')

    #fptr.close()
# Out:
# 1
# fdhlvosfpafhalll
# fdhlvosf
# pafhalll
# f
# d
# h
# l
# v
# o
# s
# f
# 4

# %% [markdown]
# above solution fails for certain testcases

# %%
import math
import os
import random
import re
import sys
from collections import Counter
# Complete the anagram function below.
def anagram(s):
    l = len(s)
    if l % 2 == 1:
        print(-1)
    else:
        count = 0
        s1, s2 = Counter(s[:l//2]), Counter(s[l//2:])
        print(s1)
        print(s2)
        for char in s2:
            current = s2[char] - s1.get(char,0)
            if current > 0:
                count += current
        print(count)
    
    
if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    q = int(input())

    for q_itr in range(q):
        s = input()

        result = anagram(s)

        #fptr.write(str(result) + '\n')

    #fptr.close()
# Out:
# 1
# fdhlvosfpafhalll
# Counter({'f': 2, 'd': 1, 'h': 1, 'l': 1, 'v': 1, 'o': 1, 's': 1})
# Counter({'l': 3, 'a': 2, 'p': 1, 'f': 1, 'h': 1})
# 5
