# %% [markdown]
# # Counting Sort 1

# %%
from IPython.display import Image

# %%
Image(filename="C:\\Users\\hp\\Desktop\\PersonalFolder\\HackerRank Code Challanges\\Counting Sort.png")

# %%
import math
import os
import random
import re
import sys

# Complete the countingSort function below.
def countingSort(arr):
    mydict = {}
    for i in range(n):
        mydict[i] = 0
    for i in arr:
        if i in mydict:
            mydict[i] += 1
    val = mydict.values()
    final = ''.join(str(i) for i in val)
    print(final)
            

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input())

    arr = list(map(int, input().rstrip().split()))

    result = countingSort(arr)

    #fptr.write(' '.join(map(str, result)))
    #fptr.write('\n')

    #fptr.close()
# Out:
# 100
# 63 25 73 1 98 73 56 84 86 57 16 83 8 25 81 56 9 53 98 67 99 12 83 89 80 91 39 86 76 85 74 39 25 90 59 10 94 32 44 3 89 30 27 79 46 96 27 32 18 21 92 69 81 40 40 34 68 78 24 87 42 69 23 41 78 22 6 90 99 89 50 30 20 1 43 3 70 95 33 46 44 9 69 48 33 60 65 16 82 67 61 32 21 79 75 75 13 87 70 33
# 0202001012101100201012111302002033100002211120201010010021011101010213200212102212121122032110111022

# %% [markdown]
# Above function fails for longer test case values like 1000 due to time constraint

# %% [markdown]
# # Other Solutions

# %%
k = int(input())
results = [0]*k

for i in input().split(' '):
    results[int(i)] += 1

if k != 100:
    print(' '.join([repr(num) for num in results if num]))
else:
    print(' '.join([repr(num) for num in results]))

# %%
__ = input()

sol = [0] * 100
for i in [int(n) for n in input().split()]:
    sol[i] += 1

print(*sol)

# %%
n = int(input())
l = [0]*100
for i in map(int,input().split()):
    l[i]+=1
print(*l)
