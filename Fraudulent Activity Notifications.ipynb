# %% [markdown]
# # Fraudulent Activity Notifications

# %%
from IPython.display import Image
from IPython.display import display

# %%
x = Image(filename=r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Fraudulent Activity.png')
y = Image(filename=r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Fraudulent Activity1.png')
z = Image(filename=r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Fraudulent Activity2.png')
display(x,y,z)

# %%
import math
import os
import random
import re
import sys
import statistics

# Complete the activityNotifications function below.
def activityNotifications(expenditure, d):
    cnt = 0
    for i in range(d, len(expenditure)):
        tmp = expenditure[i-d:i]
        print(tmp)
        mn = statistics.median(tmp)
        if expenditure[i] >= 2* mn:
            cnt += 1
    print(cnt)
    

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    nd = input().split()

    n = int(nd[0])

    d = int(nd[1])

    expenditure = list(map(int, input().rstrip().split()))

    result = activityNotifications(expenditure, d)

    #fptr.write(str(result) + '\n')

    #fptr.close()
# Out:
# 9 5
# 2 3 4 2 3 6 8 4 5
# [2, 3, 4, 2, 3]
# [3, 4, 2, 3, 6]
# [4, 2, 3, 6, 8]
# [2, 3, 6, 8, 4]
# 2

# %%
def get_median(counts, mids):
    res = []
    for mid in mids:
        print('mid', mid)
        gone = 0
        for i, v in enumerate(counts):
            print('v',v)
            gone += v
            if gone >= mid:
                res.append(i)
                break
    print('res', res)
    return sum(res) / len(res)


# Complete the activityNotifications function below.
def activityNotifications(expenditure, d):
    alerts = 0
    counts = [0] * 201

    if d % 2 == 1:
        mids = [d // 2 + 1]
    else:
        mids = [d // 2, d // 2 + 1]

    for v in expenditure[:d]:
        counts[v] += 1  #incrementing count list based on values from expenditure

    for i, exp in enumerate(expenditure[d:]):
        median = get_median(counts, mids)

        if exp >= 2 * median:
            alerts += 1
        
        old_value = expenditure[i]
        counts[old_value] -= 1
        counts[exp] += 1
        
    print(alerts)

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    nd = input().split()

    n = int(nd[0])

    d = int(nd[1])

    expenditure = list(map(int, input().rstrip().split()))

    result = activityNotifications(expenditure, d)

    #fptr.write(str(result) + '\n')

    #fptr.close()
# Out:
# 9 5
# 2 3 4 2 3 6 8 4 5
# mid 3
# v 0
# v 0
# v 2
# v 2
# res [3]
# mid 3
# v 0
# v 0
# v 1
# v 2
# res [3]
# mid 3
# v 0
# v 0
# v 1
# v 1
# v 1
# res [4]
# mid 3
# v 0
# v 0
# v 1
# v 1
# v 1
# res [4]
# 2
