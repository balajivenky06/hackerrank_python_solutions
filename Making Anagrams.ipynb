# %% [markdown]
# # Making Anagrams

# %%
from IPython.display import Image
from IPython.display import display

# %%
a = Image(r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Making Anagrams.png')
b = Image(r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Making Anagrams1.png')
c = Image(r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Making Anagrams2.png')
display(a,b,c)

# %%
import math
import os
import random
import re
import sys
from collections import Counter

# Complete the makingAnagrams function below.
def makingAnagrams(s1, s2):
    k = list(s1)
    l = list()
    for m in s2:
        if m in k:
            k.remove(m)
        else:
            l.append(m)
    return(len(k)+len(l))

    
if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    s1 = input()

    s2 = input()

    result = makingAnagrams(s1, s2)

    #fptr.write(str(result) + '\n')

    #fptr.close()
# Out:
# abc
# cde
# Counter({'a': 1, 'b': 1, 'c': 1})

# %%
#Alternate solution
same = 0
s1 = list(s1)
s2 = list(s2)
for i in s1:
    if i in s2:
        s2.remove(i)
        same += 1
return (len(s1) - same) + len(s2
