# %% [markdown]
# # Counting Sort 2

# %%
from IPython.display import display
from IPython.display import Image

# %%
a = Image(filename=r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Counting Sort 2a.png')
b = Image(filename=r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Counting Sort 2b.png')
display(a,b)

# %%
import math
import os
import random
import re
import sys

# Complete the countingSort function below.
def countingSort(arr):
    out = [0] * 100
    for i in arr:
        out[i] += 1
    
    sort = []
    for i, n in enumerate(out):
        sort.extend([i] * n)  

    print(sort)

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input())

    arr = list(map(int, input().rstrip().split()))

    result = countingSort(arr)

    #fptr.write(' '.join(map(str, result)))
    #fptr.write('\n')

    #fptr.close()
# Out:
# 5
# 1 2 5 1 4
# [1, 1, 2, 4, 5]
