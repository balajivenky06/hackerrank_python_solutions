# %% [markdown]
# # Alternating Characters

# %%
from IPython.display import display
from IPython.display import Image

# %%
a = Image(r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Alternating Characters.png')
b = Image(r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Alternating Characters-1.png')
display(a,b)

# %%
import math
import os
import random
import re
import sys

# Complete the alternatingCharacters function below.
def alternatingCharacters(s):
    dele = 0
    for i in range(len(s)):
        if i == 0:
            tmp = s[i]
        else:
            if s[i] == tmp:
                dele += 1
            tmp = s[i]
    return(dele)
                
        
    
if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    q = int(input())

    for q_itr in range(q):
        s = input()

        result = alternatingCharacters(s)

        #fptr.write(str(result) + '\n')

    #fptr.close()
# Out:
# 1
# aaabbb
# 4
