# %% [markdown]
# # Beautiful Binary String

# %%
from IPython.display import display
from IPython.display import Image

# %%
a = Image(filename=r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Beautiful Binary String.png')
b = Image(filename=r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Beautiful Binary String-1.png')
c = Image(filename=r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Beautiful Binary String-2.png')
display(a,b,c)

# %%
import math
import os
import random
import re
import sys

# Complete the beautifulBinaryString function below.
def beautifulBinaryString(b):
    cnt = b.strip().count('010')
    cnt_1 = (len(b) - len(b.replace('010',''))) //3
    print(cnt)
    print(cnt_1)

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input())

    b = input()

    result = beautifulBinaryString(b)

    #fptr.write(str(result) + '\n')

    #fptr.close()
# Out:
# 1
# 0100101010
# 3
# 3
