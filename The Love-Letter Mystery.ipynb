# %% [markdown]
# # The Love-Letter Mystery

# %%
from IPython.display import display
from IPython.display import Image

# %%
a = Image(filename=r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\The Love-Letter Mystery.png')
b = Image(filename=r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\The Love-Letter Mystery1.png')
display(a,b)

# %%
import math
import os
import random
import re
import sys

# Complete the theLoveLetterMystery function below.
def theLoveLetterMystery(s):
    for i in range(len(s) //  2 ):
        #print(s[i] + ' ' + str(ord(s[i])))
        #print(s[len(s) - i - 1] + ' ' + str(ord(s[len(s) - i - 1])) )
        out = 0
        out += abs(ord(s[i]) - ord(s[len(s) - i - 1]))
    print(out)

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    q = int(input())

    for q_itr in range(q): 
        s = input()

        result = theLoveLetterMystery(s)

        #fptr.write(str(result) + '\n')

    #fptr.close()
# Out:
# 1
# abc
# 2
