# %% [markdown]
# # Hacker Rank in a String !!

# %%
from IPython.display import Image
from IPython.display import display

# %%
x = Image(filename=r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\HackerRank in a String.png')
y = Image(filename=r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\HackerRank in a String - 1.png')
z = Image(filename=r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\HackerRank in a String - 2.png')
display(x,y,z)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

# Complete the hackerrankInString function below.
def hackerrankInString(s):
    p = 0
    for e in 'hackerrank':
        print(e)
        if e in s[p:]:
            print('S', s)
            p = s.index(e,p)+1
            print('p', p)
        else:
            return 'NO'
    return 'YES'

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    q = int(input())

    for q_itr in range(q):
        s = input()

        result = hackerrankInString(s)

        #fptr.write(result + '\n')

    #fptr.close()
# Out:
# 1
# hereiamstackerrank
# h
# S hereiamstackerrank
# p 1
# a
# S hereiamstackerrank
# p 6
# c
# S hereiamstackerrank
# p 11
# k
# S hereiamstackerrank
# p 12
# e
# S hereiamstackerrank
# p 13
# r
# S hereiamstackerrank
# p 14
# r
# S hereiamstackerrank
# p 15
# a
# S hereiamstackerrank
# p 16
# n
# S hereiamstackerrank
# p 17
# k
# S hereiamstackerrank
# p 18
