# %% [markdown]
# # Find the Median

# %%
from IPython.display import display
from IPython.display import Image

# %%
a = Image(filename=r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Find the Median.png')
b = Image(filename=r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Find the Median1.png')
display(a,b)

# %%
import math
import os
import random
import re
import sys

# Complete the findMedian function below.
def findMedian(arr):
    arr = sorted(arr)
    print(arr[len(arr)//2])

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input())

    arr = list(map(int, input().rstrip().split()))

    result = findMedian(arr)

    #fptr.write(str(result) + '\n')

    #fptr.close()
# Out:
# 7
# 0 1 2 4 6 5 3
# 3
