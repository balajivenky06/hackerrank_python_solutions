# %% [markdown]
# # Two Strings

# %%
from IPython.display import Image
from IPython.display import display

# %%
a = Image(r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Two Strings.png')
b = Image(r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Two Strings1.png')
display(a,b)

# %%
import math
import os
import random
import re
import sys

# Complete the twoStrings function below.
def twoStrings(s1, s2):
    cnt = 0
    for i in s1:
        if i in s2:
            cnt +=1
    return 'YES' if cnt > 0 else 'NO'    
    
if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    q = int(input())

    for q_itr in range(q):
        s1 = input()

        s2 = input()

        result = twoStrings(s1, s2)

        #fptr.write(result + '\n')

    #fptr.close()
# Out:
# 1
# hello
# world
# hello
# world
