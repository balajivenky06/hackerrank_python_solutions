# %% [markdown]
# # Funny String

# %%
from IPython.display import Image
from IPython.display import display

# %%
a = Image(r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Funny String.png')
b = Image(r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Funny String - 1.png')
c = Image(r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Funny String - 2.png')
display(a,b,c)

# %%
import math
import os
import random
import re
import sys

# Complete the funnyString function below.
def funnyString(s):
    s_diff = []
    for i in range(len(s)):
        if i == 0:
            tmp = ord(s[i])
        else:
            s_diff.append(abs(ord(s[i]) -  tmp))
            tmp = ord(s[i])
    if s_diff == s_diff[::-1]:
        print('Funny')
    else:
        print('Not Funny')
    

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    q = int(input())

    for q_itr in range(q):
        s = input()

        result = funnyString(s)

        #fptr.write(result + '\n')

    #fptr.close()
