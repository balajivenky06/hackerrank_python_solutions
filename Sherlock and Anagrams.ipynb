# %% [markdown]
# # Sherlock and Anagrams

# %%
from IPython.display import Image
from IPython.display import display

# %%
a = Image(r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Sherlock and Anagrams.png')
b = Image(r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Sherlock and Anagrams1.png')
c = Image(r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Sherlock and Anagrams2.png')
display(a,b,c)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

# Complete the sherlockAndAnagrams function below.
def sherlockAndAnagrams(s):
    anag = 0
    map = {}
    for i in range(len(s)):
        print('i', i)
        for j in range(len(s)-i):
            s1 = ''.join(sorted(s[j:j+i+1]))
            print(s1)
            map[s1] = map.get(s1, 0) + 1
        print('map:', map)
    for key in map:
        anag += (map[key] - 1) * map[key] //2
    print(anag)

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    q = int(input())

    for q_itr in range(q):
        s = input()

        result = sherlockAndAnagrams(s)

        #fptr.write(str(result) + '\n')

    #fptr.close()
# Out:
# 1
# abab
# i 0
# a
# b
# a
# b
# map: {'a': 2, 'b': 2}
# i 1
# ab
# ab
# ab
# map: {'a': 2, 'b': 2, 'ab': 3}
# i 2
# aab
# abb
# map: {'a': 2, 'b': 2, 'ab': 3, 'aab': 1, 'abb': 1}
# i 3
# aabb
# map: {'a': 2, 'b': 2, 'ab': 3, 'aab': 1, 'abb': 1, 'aabb': 1}
# 5

# %%
from collections import Counter

def count_anagrams(string):
    buckets = {}
    for i in range(len(string)):
        for j in range(1, len(string) - i + 1):
            key = frozenset(Counter(string[i:i+j]).items()) # O(N) time key extract
            buckets[key] = buckets.get(key, 0) + 1
    count = 0
    for key in buckets:
        count += buckets[key] * (buckets[key]-1) // 2
    return count

# %%
dict={}

count=0

for i in range(len(s)):

    for j in range(i+1,len(s)+1):

        list1= list(s[i:j].strip())

        list1.sort()

        transf=''.join(list1)

        if transf in dict: 

            count+=dict[transf]

            dict[transf]=dict[transf]+1

        else: dict[transf]=1       

return count

# %%
def sherlockAndAnagrams(s):
    anagram_dict = {}
    count = 0
    for i in range(1, len(s)):
        for j in range(len(s)-i+1):
            current_sorted = str(sorted(s[j:j+i]))
            if (current_sorted not in anagram_dict):
                anagram_dict[current_sorted] = 1
            else:
                count += anagram_dict[current_sorted]
                anagram_dict[current_sorted] += 1
    return count
