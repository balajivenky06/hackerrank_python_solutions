# %% [markdown]
# # Insertion Sort Advanced Analysis

# %%
from IPython.display import Image
from IPython.display import display

# %%
a = Image(r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Insertion Sort Advanced Analysis.png')
b = Image(r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Insertion Sort Advanced Analysis1.png')
c = Image(r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Insertion Sort Advanced Analysis2.png')
display(a,b,c)

# %%
import math
import os
import random
import re
import sys

# Complete the insertionSort function below.
def insertionSort(arr):
    tot = 0
    for i in range(len(arr)):
        cnt=0
        for j in range(i):
            if arr[j] > arr[i]:
                arr[j],arr[i] = arr[i],arr[j]
                print(i-j)
                print(arr)
                break
    print(tot)

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    t = int(input())

    for t_itr in range(t):
        n = int(input())

        arr = list(map(int, input().rstrip().split()))

        result = insertionSort(arr)

        #fptr.write(str(result) + '\n')

    #fptr.close()
# Out:
# 1
# 5
# 2 1 3 1 2
# 1
# [1, 2, 3, 1, 2]
# 2
# [1, 1, 3, 2, 2]
# 2
# [1, 1, 2, 2, 3]
# 0

# %% [markdown]
# # Above Solution not working properly.... Need to think with other logics... Brute force cant help
