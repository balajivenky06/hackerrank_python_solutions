# %% [markdown]
# # Lily's Homework

# %%
from IPython.display import Image
from IPython.display import display

# %%
x = Image(filename=r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Lily Homework - 1.png')
y = Image(filename=r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Lily Homework - 1a.png')
display(x,y)

# %%
import math
import os
import random
import re
import sys

# Complete the lilysHomework function below.
def lilysHomework(arr):
    cnt1 = rev_lilysHomework(arr) #run the same below algo for reversed array
    m ={}
    for i in range(len(arr)): #creating dict with Keys as values from input, values as index of value from input
        m[arr[i]] = i
    
    sor_arr = sorted(arr) #create a copy of sorted input list
    cnt = 0
    
    for i in range(len(arr)): #Iterate throught the input list, compare current value of list against sorted arrary list
        if arr[i] != sor_arr[i]: #If different
            cnt += 1 #Increment the no of swaps count
        ind_to_swap = m[sor_arr[i]] # get the index of sorted array value from dict
        m[arr[i]] = m[sor_arr[i]] #
        arr[i], arr[ind_to_swap] = sor_arr[i], arr[i] # swap the values 
    
    print(min(cnt, cnt1))

def rev_lilysHomework(arr):
    arr = arr[::-1]
    m ={}
    for i in range(len(arr)):
        m[arr[i]] = i
    sor_arr = sorted(arr)
    cnt = 0
    
    for i in range(len(arr)):
        if arr[i] != sor_arr[i]:
            cnt += 1
        ind_to_swap = m[sor_arr[i]]
        m[arr[i]] = m[sor_arr[i]]
        arr[i], arr[ind_to_swap] = sor_arr[i], arr[i]
    return(cnt)
    
if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input())

    arr = list(map(int, input().rstrip().split()))

    result = lilysHomework(arr)

    #fptr.write(str(result) + '\n')

    #fptr.close
# Out:
# 5
# 3 4 2 5 1
# 2

# %% [markdown]
# asc=solution(list(a))
# desc=solution(list(reversed(a)))
# print min(asc,desc)
