# %% [markdown]
# # String Construction

# %%
from IPython.display import Image
from IPython.display import display

# %%
a = Image(r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\String Construction.png')
b = Image(r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\String Construction1.png')
c = Image(r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\String Construction2.png')
display(a,b,c)

# %%
import math
import os
import random
import re
import sys
from collections import Counter

# Complete the stringConstruction function below.
def stringConstruction(s):
    s = len(set(s))
    print(s)

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    q = int(input())

    for q_itr in range(q):
        s = input()

        result = stringConstruction(s)

        #fptr.write(str(result) + '\n')

    #fptr.close()
# Out:
# 2
# abcd
# 4
# abab
# 2
