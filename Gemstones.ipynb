# %% [markdown]
# # Gemstones

# %%
from IPython.display import display
from IPython.display import Image

# %%
a = Image(r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Gemstones.png')
b = Image(r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Gemstones - 1.png')
display(a,b)

# %%
import math
import os
import random
import re
import sys

# Complete the gemstones function below.
def gemstones(arr):
    for i in range(len(arr)):
        arr[i] = set(arr[i])
    gems = set.intersection(*arr)
    print(len(gems))



if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input())

    arr = []

    for _ in range(n):
        arr_item = input()
        arr.append(arr_item)

    result = gemstones(arr)

    #fptr.write(str(result) + '\n')

    #fptr.close()
# Out:
# 3
# AKLJ
# a
# dskj
# 0
