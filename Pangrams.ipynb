# %%
from IPython.display import Image
from IPython.display import display

# %%
x = Image(filename=r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Pangrams.png')
y = Image(filename=r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Pangrams-1.png')
display(x,y)

# %%
import math
import os
import random
import re
import sys

# Complete the pangrams function below.
def pangrams(s):
    print('pangram') if len(set([i.lower() for i in s]) & set('abcdefghijklmnopqrstuvwxyz')) == 26 else print('not pangram')

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    s = input()

    result = pangrams(s)

    #fptr.write(result + '\n')

    #fptr.close()
# Out:
# We promptly judged antique ivory buckles for the prize
# not pangram
