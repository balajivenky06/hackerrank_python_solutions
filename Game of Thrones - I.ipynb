# %% [markdown]
# # Game of Thrones - I

# %%
from IPython.display import Image
from IPython.display import display

# %%
a = Image(r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Game of Thrones.png')
b = Image(r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Game of Thrones1.png')
c = Image(r'C:\Users\hp\Desktop\PersonalFolder\HackerRank Code Challanges\Game of Thrones2.png')
display(a,b,c)

# %%
import math
import os
import random
import re
import sys
from collections import Counter

# Complete the gameOfThrones function below.
def gameOfThrones(s):
    diff = 0
    for x in Counter(s).values():
        diff += x%2
    return "NO" if diff > 1 else "YES"

if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    s = input()

    result = gameOfThrones(s)

    #fptr.write(result + '\n')

    #fptr.close()
# Out:
# cdcdcdcdeeeef
